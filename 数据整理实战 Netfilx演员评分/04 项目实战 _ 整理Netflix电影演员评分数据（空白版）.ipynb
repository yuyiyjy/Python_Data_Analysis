# %% [markdown]
# # 项目：整理Netflix电影演员评分数据

# %% [markdown]
# ## 分析目标

# %% [markdown]
# 此数据分析的目的是，整理不同流派影视作品，比如喜剧片、动作片、科幻片中，各演员出演作品的平均IMDB评分，从而挖掘出各个流派中的高评分作品演员。
#
# 本实战项目的目的在于练习整理数据，从而得到可供下一步分析的数据。

# %% [markdown]
# ## 简介

# %% [markdown]
# 原始数据集记录了截止至2022年7月美国地区可观看的所有Netflix电视剧及电影数据。数据集包含两个数据表：`titles.csv`和`credits.csv`。
#
# `titles.csv`包含电影及电视剧相关信息，包括影视作品ID、标题、类型、描述、流派、IMDB（一个国外的在线评分网站）评分，等等。`credits.csv`包含超过7万名出现在Netflix影视作品的导演及演员信息，包括名字、影视作品ID、人物名、演职员类型（导演/演员）等。

# %% [markdown]
# `titles.csv`每列的含义如下：
# - id：影视作品ID。
# - title：影视作品标题。
# - show_type：作品类型，电视节目或电影。
# - description：简短描述。
# - release_year：发布年份。
# - age_certification：适龄认证。
# - runtime：每集电视剧或电影的长度。
# - genres：流派类型列表。
# - production_countries：出品国家列表。
# - seasons：如果是电视剧，则是季数。
# - imdb_id：IMDB的ID。
# - imdb_score：IMDB的评分。
# - imdb_votes：IMDB的投票数。
# - tmdb_popularity：TMDB的流行度。
# - tmdb_score：TMDB的评分。
#
# `credits.csv`每列的含义如下：
# - person_ID：演职员ID。
# - id：参与的影视作品ID。
# - name：姓名。
# - character_name：角色姓名。
# - role：演职员类型，演员或导演。

# %% [markdown]
# ## 一.数据评估与清理

# %%
import pandas as pd

# %%
original_titles=pd.read_csv("./titles.csv")

# %%
original_credits=pd.read_csv("./credits.csv")

# %%
clean_titles=original_titles.copy()
clean_credits=original_credits.copy()

# %% [markdown]
# ### 1.乱数据评估与清理

# %%
original_titles.head()
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 4  tm120801                      The Dirty Dozen  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# 3  King Arthur, accompanied by his squire, recrui...          1975
# 4  12 American military prisoners in World War II...          1967
#
#   age_certification  runtime                                       genres  \
# 0             TV-MA       51                            ['documentation']
# 1                 R      114                           ['drama', 'crime']
# 2                 R      109  ['drama', 'action', 'thriller', 'european']
# 3                PG       91              ['fantasy', 'action', 'comedy']
# 4               NaN      150                            ['war', 'action']
#
#   production_countries  seasons    imdb_id  imdb_score  imdb_votes  \
# 0               ['US']      1.0        NaN         NaN         NaN
# 1               ['US']      NaN  tt0075314         8.2    808582.0
# 2               ['US']      NaN  tt0068473         7.7    107673.0
# 3               ['GB']      NaN  tt0071853         8.2    534486.0
# 4         ['GB', 'US']      NaN  tt0061578         7.7     72662.0
#
#    tmdb_popularity  tmdb_score
# 0            0.600         NaN
# 1           40.965       8.179
# 2           10.010       7.300
# 3           15.461       7.811
# 4           20.398       7.600

# %% [markdown]
# ### 观察发现genres和production_countries这两列中存在多个值的情况，因此需要拆分

# %%
clean_titles["genres"][2]
# Out:
# "['drama', 'action', 'thriller', 'european']"

# %%
clean_titles["production_countries"][4]
# Out:
# "['GB', 'US']"

# %% [markdown]
# ### 发现genres和production_countries是字符串并非列表，因此需要先转换成列表

# %%
clean_titles["genres"]=clean_titles["genres"].apply(lambda x:eval(x))

# %%
clean_titles["genres"][2]
# Out:
# ['drama', 'action', 'thriller', 'european']

# %%
clean_titles["production_countries"]=clean_titles["production_countries"].apply(lambda x:eval(x))

# %%
clean_titles["production_countries"][4]
# Out:
# ['GB', 'US']

# %% [markdown]
# ### 转换完成后可以调用explode方法来拆分

# %%
clean_titles=clean_titles.explode("genres")
clean_titles=clean_titles.explode("production_countries")

# %%
clean_titles.sample(10)
# Out:
#             id                                    title   type  \
# 306   tm159901  Miss Congeniality 2: Armed and Fabulous  MOVIE
# 3653  tm885805                          Debt Collectors  MOVIE
# 5346  ts302056                           Titletown High   SHOW
# 4371  tm460259                          Blood Will Tell  MOVIE
# 4635  tm476496                 Bhai - Vyakti Ki Valli 2  MOVIE
# 2876  tm429174                                 Gun City  MOVIE
# 4533  tm476922                       Wanted - Matloubin  MOVIE
# 4403  tm918258                               Dogwashers  MOVIE
# 1307   ts36630                                 Dinotrux   SHOW
# 3325  tm498034                     The Last Blockbuster  MOVIE
#
#                                             description  release_year  \
# 306   After her triumph at the Miss United States pa...          2005
# 3653  A pair of debt collectors are thrust into an e...          2020
# 5346  In a Georgia town where football rules and win...          2021
# 4371  Thriller about a family whose ties are put to ...          2019
# 4635  The second part of the P.L Deshpande biopic wh...          2019
# 2876  Barcelona, ​​Spain, 1921. A tough cop from Mad...          2018
# 4533  Wanted is a very human comedy about four old p...          2019
# 4403  When a narco past his prime refuses to pay a d...          2020
# 1307  Half dinosaur, half construction truck, full-o...          2015
# 3325  A documentary on the last remaining Blockbuste...          2020
#
#      age_certification  runtime         genres production_countries  seasons  \
# 306              PG-13      115          crime                   US      NaN
# 3653                 R       97         comedy                   US      NaN
# 5346             TV-14       34          sport                   US      1.0
# 4371               NaN      113          drama                   AR      NaN
# 4635                 R      130          drama                   IN      NaN
# 2876               NaN      127        history                   FR      NaN
# 4533               NaN       90         comedy                   LB      NaN
# 4403               NaN      107          drama                   AR      NaN
# 1307             TV-Y7       23         family                   US      5.0
# 3325               NaN       86  documentation                   US      NaN
#
#          imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 306    tt0385307         5.1     74637.0           21.495       5.700
# 3653  tt10933680         5.8      4347.0           15.007       6.100
# 5346  tt15192032         5.5       332.0            2.146       5.600
# 4371   tt5687236         6.1       831.0            2.268       6.000
# 4635   tt9680076         7.6       203.0            1.015       8.000
# 2876   tt7104984         6.3      3895.0            6.610       6.400
# 4533   tt9194246         4.5       615.0              NaN         NaN
# 4403  tt13248198         5.8       601.0           29.101       6.313
# 1307   tt1396212         6.7       465.0            8.914       7.400
# 3325   tt8704802         6.7      5448.0            8.213       6.600

# %%
original_credits.head()
# Out:
#    person_id       id             name                character   role
# 0       3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                      Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                    Betsy  ACTOR

# %% [markdown]
# ### 观察发现credits没有什么结构问题

# %% [markdown]
# ### 2.脏数据评估与清理

# %% [markdown]
# ### （1）缺失数据

# %%
clean_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17818 entries, 0 to 5849
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    17818 non-null  object
#  1   title                 17817 non-null  object
#  2   type                  17818 non-null  object
#  3   description           17790 non-null  object
#  4   release_year          17818 non-null  int64
#  5   age_certification     10889 non-null  object
#  6   runtime               17818 non-null  int64
#  7   genres                17755 non-null  object
#  8   production_countries  17439 non-null  object
#  9   seasons               6224 non-null   float64
#  10  imdb_id               17116 non-null  object
#  11  imdb_score            16976 non-null  float64
#  12  imdb_votes            16945 non-null  float64
#  13  tmdb_popularity       17663 non-null  float64
#  14  tmdb_score            17241 non-null  float64
# dtypes: float64(5), int64(2), object(8)
# memory usage: 2.2+ MB

# %% [markdown]
# ### 在我们关心的数据id、genres和imdb_score中，genres和imdb_score中存在缺失，另外发现release_year应该为日期类型而非整型

# %%
clean_titles["release_year"]=pd.to_datetime(clean_titles["release_year"])

# %%
clean_titles["release_year"]
# Out:
# 0      1970-01-01 00:00:00.000001945
# 1      1970-01-01 00:00:00.000001976
# 1      1970-01-01 00:00:00.000001976
# 2      1970-01-01 00:00:00.000001972
# 2      1970-01-01 00:00:00.000001972
#                     ...
# 5847   1970-01-01 00:00:00.000002021
# 5848   1970-01-01 00:00:00.000002021
# 5849   1970-01-01 00:00:00.000002021
# 5849   1970-01-01 00:00:00.000002021
# 5849   1970-01-01 00:00:00.000002021
# Name: release_year, Length: 17818, dtype: datetime64[ns]

# %%
clean_titles[clean_titles["genres"].isnull()]
# Out:
#              id                                      title   type  \
# 212    tm255589                              One Last Shot  MOVIE
# 619    tm341561                    Like Twenty Impossibles  MOVIE
# 632     ts86241               Le Robe De Mariage Des Cieux   SHOW
# 636    tm404676                       To and from New York  MOVIE
# 637     tm89054                        Osuofia in London 2  MOVIE
# ...         ...                                        ...    ...
# 5799  tm1040959                 The Circle: The Afterparty  MOVIE
# 5802   ts302434    Plastic Cup Boyz: Laughing My Mask Off!   SHOW
# 5840  tm1216735                            Sun of the Soil  MOVIE
# 5844  tm1074617              Bling Empire - The Afterparty  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
#
#                                             description  \
# 212   In this low-budget short film, two best buddie...
# 619   Occupied Palestine: A serene landscape now poc...
# 632   It was with much difficulty that Ai Qing was a...
# 636   While covering a story in New York City, a Sea...
# 637   Osuofia return to his Nigerian village with a ...
# ...                                                 ...
# 5799  Stars of The Circle drop by to discuss Season ...
# 5802  Comedy collective The Plastic Cup Boyz pour ou...
# 5840  In 14th-century Mali, an ambitious young royal...
# 5844  The stars of "Bling Empire" discuss the show's...
# 5848  Jamie Foxx, David Alan Grier and more from the...
#
#                       release_year age_certification  runtime genres  \
# 212  1970-01-01 00:00:00.000001998               NaN       30    NaN
# 619  1970-01-01 00:00:00.000002003               NaN       16    NaN
# 632  1970-01-01 00:00:00.000002004             TV-MA       63    NaN
# 636  1970-01-01 00:00:00.000002006               NaN       82    NaN
# 637  1970-01-01 00:00:00.000002004               NaN       72    NaN
# ...                            ...               ...      ...    ...
# 5799 1970-01-01 00:00:00.000002021               NaN       35    NaN
# 5802 1970-01-01 00:00:00.000002021               NaN       33    NaN
# 5840 1970-01-01 00:00:00.000002022               NaN       26    NaN
# 5844 1970-01-01 00:00:00.000002021               NaN       35    NaN
# 5848 1970-01-01 00:00:00.000002021             PG-13       37    NaN
#
#      production_countries  seasons imdb_id  imdb_score  imdb_votes  \
# 212                   NaN      NaN     NaN         NaN         NaN
# 619                    PS      NaN     NaN         NaN         NaN
# 632                   NaN      1.0     NaN         NaN         NaN
# 636                    US      NaN     NaN         NaN         NaN
# 637                    XX      NaN     NaN         NaN         NaN
# ...                   ...      ...     ...         ...         ...
# 5799                   US      NaN     NaN         NaN         NaN
# 5802                  NaN      1.0     NaN         NaN         NaN
# 5840                  NaN      NaN     NaN         NaN         NaN
# 5844                   US      NaN     NaN         NaN         NaN
# 5848                   US      NaN     NaN         NaN         NaN
#
#       tmdb_popularity  tmdb_score
# 212             1.890         5.2
# 619             0.812         6.5
# 632             0.600         NaN
# 636             1.401         5.8
# 637             1.091         NaN
# ...               ...         ...
# 5799            1.882        10.0
# 5802            0.683         NaN
# 5840            1.179         7.0
# 5844              NaN         NaN
# 5848            1.296        10.0
#
# [63 rows x 15 columns]

# %%
clean_titles[(clean_titles["genres"].isnull()) & (~clean_titles["imdb_score"].isnull())]
# Out:
#              id                                              title   type  \
# 1813    ts77824  My Next Guest Needs No Introduction With David...   SHOW
# 1939   ts215037                              Minecraft: Story Mode   SHOW
# 2386    ts74805                   A Little Help with Carol Burnett   SHOW
# 2658   ts265844                                           #ABtalks   SHOW
# 4274  tm1172010                                  The Lockdown Plan  MOVIE
# 4648  tm1113921                                           In Vitro  MOVIE
#
#                                             description  \
# 1813  TV legend David Letterman teams up with fascin...
# 1939  MInecraft: Story Mode is an interactive, anima...
# 2386  In this unscripted series starring comedy lege...
# 2658  #ABtalks is a YouTube interview show hosted by...
# 4274                                                NaN
# 4648  'In Vitro' is an otherworldly rumination on me...
#
#                       release_year age_certification  runtime genres  \
# 1813 1970-01-01 00:00:00.000002018             TV-MA       50    NaN
# 1939 1970-01-01 00:00:00.000002018             TV-PG       52    NaN
# 2386 1970-01-01 00:00:00.000002018              TV-G       24    NaN
# 2658 1970-01-01 00:00:00.000002018             TV-PG       68    NaN
# 4274 1970-01-01 00:00:00.000002020               NaN       49    NaN
# 4648 1970-01-01 00:00:00.000002019               NaN       27    NaN
#
#      production_countries  seasons     imdb_id  imdb_score  imdb_votes  \
# 1813                   US      4.0   tt7829834         7.8      5581.0
# 1939                   US      1.0  tt10498322         5.6       347.0
# 2386                   US      1.0   tt7204366         6.3       237.0
# 2658                  NaN      1.0  tt12635254         9.6         7.0
# 4274                  NaN      NaN  tt13079112         6.5         NaN
# 4648                  NaN      NaN  tt10545994         7.7         NaN
#
#       tmdb_popularity  tmdb_score
# 1813            8.217         7.6
# 1939              NaN         NaN
# 2386            1.621         6.2
# 2658              NaN         NaN
# 4274              NaN         NaN
# 4648              NaN         NaN

# %% [markdown]
# ### 观察发现少数数据genres缺失但imdb_score没有缺失，但这部分数据仍然需要删除

# %%
clean_titles=clean_titles.dropna(subset=["genres"])

# %%
clean_titles[clean_titles["genres"].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, title, type, description, release_year, age_certification, runtime, genres, production_countries, seasons, imdb_id, imdb_score, imdb_votes, tmdb_popularity, tmdb_score]
# Index: []

# %%
clean_titles[clean_titles["imdb_score"].isnull()]
# Out:
#              id                                title   type  \
# 0      ts300399  Five Came Back: The Reference Films   SHOW
# 75     tm132164                 Bill Hicks: Sane Man  MOVIE
# 145    ts251477                      My First Errand   SHOW
# 145    ts251477                      My First Errand   SHOW
# 145    ts251477                      My First Errand   SHOW
# ...         ...                                  ...    ...
# 5790  tm1094060               My Heroes Were Cowboys  MOVIE
# 5791  tm1047429              Alan Saldaña: Locked Up  MOVIE
# 5810  tm1225897                           Social Man  MOVIE
# 5810  tm1225897                           Social Man  MOVIE
# 5833   ts307884                           HQ Barbers   SHOW
#
#                                             description  \
# 0     This collection includes 12 World War II-era p...
# 75    Sane Man was filmed before Bill recorded ‘Dang...
# 145   “Hajimete no Otsukai” (First Errand) is a Japa...
# 145   “Hajimete no Otsukai” (First Errand) is a Japa...
# 145   “Hajimete no Otsukai” (First Errand) is a Japa...
# ...                                                 ...
# 5790  Robin Wiltshire's painful childhood was rescue...
# 5791  Mexican comedian Alan Saldaña is back, poking ...
# 5810  Two competitive social media Influencers go he...
# 5810  Two competitive social media Influencers go he...
# 5833  When a family run barber shop in the heart of ...
#
#                       release_year age_certification  runtime         genres  \
# 0    1970-01-01 00:00:00.000001945             TV-MA       51  documentation
# 75   1970-01-01 00:00:00.000001989                 R       80         comedy
# 145  1970-01-01 00:00:00.000001991              TV-G       18  documentation
# 145  1970-01-01 00:00:00.000001991              TV-G       18         family
# 145  1970-01-01 00:00:00.000001991              TV-G       18        reality
# ...                            ...               ...      ...            ...
# 5790 1970-01-01 00:00:00.000002021                PG       23  documentation
# 5791 1970-01-01 00:00:00.000002021               NaN       49         comedy
# 5810 1970-01-01 00:00:00.000002021               NaN       96         comedy
# 5810 1970-01-01 00:00:00.000002021               NaN       96          drama
# 5833 1970-01-01 00:00:00.000002021             TV-14       24         comedy
#
#      production_countries  seasons     imdb_id  imdb_score  imdb_votes  \
# 0                      US      1.0         NaN         NaN         NaN
# 75                     US      NaN         NaN         NaN         NaN
# 145                    JP     12.0         NaN         NaN         NaN
# 145                    JP     12.0         NaN         NaN         NaN
# 145                    JP     12.0         NaN         NaN         NaN
# ...                   ...      ...         ...         ...         ...
# 5790                   US      NaN  tt15084326         NaN         NaN
# 5791                  NaN      NaN         NaN         NaN         NaN
# 5810                  NaN      NaN  tt20198164         NaN         NaN
# 5810                  NaN      NaN  tt20198164         NaN         NaN
# 5833                   NG      1.0         NaN         NaN         NaN
#
#       tmdb_popularity  tmdb_score
# 0               0.600         NaN
# 75              3.377         7.5
# 145             7.730         7.8
# 145             7.730         7.8
# 145             7.730         7.8
# ...               ...         ...
# 5790            3.145         7.7
# 5791            6.670         6.0
# 5810              NaN         NaN
# 5810              NaN         NaN
# 5833            0.840         NaN
#
# [785 rows x 15 columns]

# %%
clean_titles=clean_titles.dropna(subset=["imdb_score"])

# %%
clean_titles[clean_titles["imdb_score"].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, title, type, description, release_year, age_certification, runtime, genres, production_countries, seasons, imdb_id, imdb_score, imdb_votes, tmdb_popularity, tmdb_score]
# Index: []

# %% [markdown]
# ### 成功将titles中genres和imdb_score缺失的部分删除

# %% [markdown]
# ### titels中我们关心的数据是genres和imdb_score，而credits中我们关心的数据是person_ID、id和role

# %%
clean_credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77801 entries, 0 to 77800
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   person_id  77801 non-null  int64
#  1   id         77801 non-null  object
#  2   name       77801 non-null  object
#  3   character  68029 non-null  object
#  4   role       77801 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.0+ MB

# %% [markdown]
# ### 可见crdits中只有部分character缺失，其余数据都是完整无缺的，但person_id应该为字符串类型而非整型

# %%
clean_credits["person_id"]=clean_credits["person_id"].astype(str)

# %%
clean_credits["person_id"]
# Out:
# 0           3748
# 1          14658
# 2           7064
# 3           3739
# 4          48933
#           ...
# 77796     736339
# 77797     399499
# 77798     373198
# 77799     378132
# 77800    1950416
# Name: person_id, Length: 77801, dtype: object

# %% [markdown]
# ### （2）重复数据

# %%
print(clean_titles.duplicated().sum())
# Out:
# 0

# %%
clean_titles.head()
# Out:
#          id        title   type  \
# 1   tm84618  Taxi Driver  MOVIE
# 1   tm84618  Taxi Driver  MOVIE
# 2  tm154986  Deliverance  MOVIE
# 2  tm154986  Deliverance  MOVIE
# 2  tm154986  Deliverance  MOVIE
#
#                                          description  \
# 1  A mentally unstable Vietnam War veteran works ...
# 1  A mentally unstable Vietnam War veteran works ...
# 2  Intent on seeing the Cahulawassee River before...
# 2  Intent on seeing the Cahulawassee River before...
# 2  Intent on seeing the Cahulawassee River before...
#
#                    release_year age_certification  runtime    genres  \
# 1 1970-01-01 00:00:00.000001976                 R      114     drama
# 1 1970-01-01 00:00:00.000001976                 R      114     crime
# 2 1970-01-01 00:00:00.000001972                 R      109     drama
# 2 1970-01-01 00:00:00.000001972                 R      109    action
# 2 1970-01-01 00:00:00.000001972                 R      109  thriller
#
#   production_countries  seasons    imdb_id  imdb_score  imdb_votes  \
# 1                   US      NaN  tt0075314         8.2    808582.0
# 1                   US      NaN  tt0075314         8.2    808582.0
# 2                   US      NaN  tt0068473         7.7    107673.0
# 2                   US      NaN  tt0068473         7.7    107673.0
# 2                   US      NaN  tt0068473         7.7    107673.0
#
#    tmdb_popularity  tmdb_score
# 1           40.965       8.179
# 1           40.965       8.179
# 2           10.010       7.300
# 2           10.010       7.300
# 2           10.010       7.300

# %%
print(clean_credits.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ### 发现clean_titles和clean_credits中都没有重复数据

# %% [markdown]
# ### （3）不一致数据

# %% [markdown]
# ### 对于clean_titles，可能出现不一致数据的有production_countries和genres

# %%
pd.set_option("display.max_rows",None)

# %%
clean_titles["production_countries"].value_counts().sort_index()
# Out:
# production_countries
# AE           52
# AF            1
# AL            6
# AO            3
# AR          150
# AT           28
# AU          217
# BD            3
# BE          148
# BF            2
# BG           31
# BR          221
# BS            3
# BT            2
# BY            2
# CA          608
# CD            7
# CH           33
# CL           35
# CM            3
# CN          295
# CO           94
# CU            1
# CY            5
# CZ           22
# DE          383
# DK           89
# DZ            3
# EG           93
# ES          637
# FI           18
# FO            1
# FR          720
# GB         1068
# GE            1
# GH            6
# GL            3
# GR            4
# GT            1
# HK          102
# HR            3
# HU           18
# ID          149
# IE           49
# IL           42
# IN         1610
# IO            4
# IQ            5
# IR            7
# IS           28
# IT          224
# JO           19
# JP         1046
# KE            6
# KG            2
# KH           10
# KN            4
# KR          637
# KW           10
# LB           70
# LK            1
# LT            7
# LU           27
# Lebanon       1
# MA           15
# MC            4
# MT            8
# MU            5
# MW            2
# MX          264
# MY           30
# NG          131
# NL          102
# NO           68
# NP            1
# NZ           27
# PE           26
# PH          192
# PK            9
# PL          126
# PR            9
# PS           32
# PT           14
# PY            3
# QA           24
# RO           25
# RS            2
# RU           41
# SA           28
# SE           81
# SG           47
# SN            6
# SU            7
# SY            4
# TH           87
# TN            7
# TR          195
# TW          133
# TZ            4
# UA            8
# US         5648
# UY           15
# VA            2
# VE            2
# VN            8
# XX           43
# ZA          103
# ZW            2
# Name: count, dtype: int64

# %% [markdown]
# ### Lebanon和LB指代的应该是同一个国家，因此需要统一

# %%
clean_titles=clean_titles.replace({"Lebanon":"LB"})

# %%
clean_titles["production_countries"].value_counts().sort_index()
# Out:
# production_countries
# AE      52
# AF       1
# AL       6
# AO       3
# AR     150
# AT      28
# AU     217
# BD       3
# BE     148
# BF       2
# BG      31
# BR     221
# BS       3
# BT       2
# BY       2
# CA     608
# CD       7
# CH      33
# CL      35
# CM       3
# CN     295
# CO      94
# CU       1
# CY       5
# CZ      22
# DE     383
# DK      89
# DZ       3
# EG      93
# ES     637
# FI      18
# FO       1
# FR     720
# GB    1068
# GE       1
# GH       6
# GL       3
# GR       4
# GT       1
# HK     102
# HR       3
# HU      18
# ID     149
# IE      49
# IL      42
# IN    1610
# IO       4
# IQ       5
# IR       7
# IS      28
# IT     224
# JO      19
# JP    1046
# KE       6
# KG       2
# KH      10
# KN       4
# KR     637
# KW      10
# LB      71
# LK       1
# LT       7
# LU      27
# MA      15
# MC       4
# MT       8
# MU       5
# MW       2
# MX     264
# MY      30
# NG     131
# NL     102
# NO      68
# NP       1
# NZ      27
# PE      26
# PH     192
# PK       9
# PL     126
# PR       9
# PS      32
# PT      14
# PY       3
# QA      24
# RO      25
# RS       2
# RU      41
# SA      28
# SE      81
# SG      47
# SN       6
# SU       7
# SY       4
# TH      87
# TN       7
# TR     195
# TW     133
# TZ       4
# UA       8
# US    5648
# UY      15
# VA       2
# VE       2
# VN       8
# XX      43
# ZA     103
# ZW       2
# Name: count, dtype: int64

# %%
clean_titles["genres"].value_counts()
# Out:
# genres
# drama            3357
# comedy           2419
# thriller         1446
# action           1339
# romance          1080
# crime            1066
# documentation     981
# family            769
# animation         732
# fantasy           727
# european          679
# scifi             647
# horror            438
# history           336
# music             266
# reality           226
# war               221
# sport             188
# western            53
# Name: count, dtype: int64

# %%
clean_titles.query('genres==""')
# Out:
# Empty DataFrame
# Columns: [id, title, type, description, release_year, age_certification, runtime, genres, production_countries, seasons, imdb_id, imdb_score, imdb_votes, tmdb_popularity, tmdb_score]
# Index: []

# %% [markdown]
# ### 对于clean_crdits，可能存在不一致的数据有role

# %%
clean_credits["role"].value_counts().sort_index()
# Out:
# role
# ACTOR       73251
# DIRECTOR     4550
# Name: count, dtype: int64

# %% [markdown]
# ### 由此可见role只有导演和演员两种，但由于我们的目标是找出评分最高的演员，因此可以将导演的数据删除

# %%
clean_credits=clean_credits[clean_credits["role"]=="ACTOR"]

# %%
clean_credits[clean_credits["role"]=="DIRECTOR"]
# Out:
# Empty DataFrame
# Columns: [person_id, id, name, character, role]
# Index: []

# %% [markdown]
# ### (4）无效数据

# %%
clean_titles.describe()
# Out:
#                         release_year       runtime      seasons    imdb_score  \
# count                          16970  16970.000000  5954.000000  16970.000000
# mean   1970-01-01 00:00:00.000002015     80.912552     2.455492      6.514207
# min    1970-01-01 00:00:00.000001954      0.000000     1.000000      1.500000
# 25%    1970-01-01 00:00:00.000002015     45.000000     1.000000      5.800000
# 50%    1970-01-01 00:00:00.000002018     90.000000     2.000000      6.600000
# 75%    1970-01-01 00:00:00.000002020    107.000000     3.000000      7.300000
# max    1970-01-01 00:00:00.000002022    225.000000    42.000000      9.500000
# std                              NaN     39.596172     2.869428      1.131095
#
#          imdb_votes  tmdb_popularity    tmdb_score
# count  1.694100e+04     16842.000000  16515.000000
# mean   3.281655e+04        29.396307      6.846933
# min    5.000000e+00         0.600000      1.000000
# 25%    7.800000e+02         4.070000      6.200000
# 50%    3.508000e+03        10.195000      6.900000
# 75%    1.697800e+04        23.639000      7.500000
# max    2.294231e+06      2274.044000     10.000000
# std    1.141492e+05        93.178235      1.078831

# %%
clean_credits.describe()
# Out:
#        person_id       id         name character   role
# count      73251    73251        73251     68029  73251
# unique     51544     5340        51308     47274      1
# top        38636  tm32982  Boman Irani      Self  ACTOR
# freq          25      207           25      1950  73251

# %% [markdown]
# ### 由此可见clean_credits和clean_titles中没有无效数据

# %% [markdown]
# ### （5）保存数据

# %%
clean_titles.to_csv("./titles.cleaned.csv",index=False)
clean_credits.to_csv("./credits_cleaned.csv",index=False)

# %% [markdown]
# ## 二.数据整理

# %% [markdown]
# ### 将celan_titles和clean_credits按id进行合并

# %%
titles_with_credits=clean_titles.merge(clean_credits,on="id")
titles_with_credits.head()
# Out:
#         id        title   type  \
# 0  tm84618  Taxi Driver  MOVIE
# 1  tm84618  Taxi Driver  MOVIE
# 2  tm84618  Taxi Driver  MOVIE
# 3  tm84618  Taxi Driver  MOVIE
# 4  tm84618  Taxi Driver  MOVIE
#
#                                          description  \
# 0  A mentally unstable Vietnam War veteran works ...
# 1  A mentally unstable Vietnam War veteran works ...
# 2  A mentally unstable Vietnam War veteran works ...
# 3  A mentally unstable Vietnam War veteran works ...
# 4  A mentally unstable Vietnam War veteran works ...
#
#                    release_year age_certification  runtime genres  \
# 0 1970-01-01 00:00:00.000001976                 R      114  drama
# 1 1970-01-01 00:00:00.000001976                 R      114  drama
# 2 1970-01-01 00:00:00.000001976                 R      114  drama
# 3 1970-01-01 00:00:00.000001976                 R      114  drama
# 4 1970-01-01 00:00:00.000001976                 R      114  drama
#
#   production_countries  seasons    imdb_id  imdb_score  imdb_votes  \
# 0                   US      NaN  tt0075314         8.2    808582.0
# 1                   US      NaN  tt0075314         8.2    808582.0
# 2                   US      NaN  tt0075314         8.2    808582.0
# 3                   US      NaN  tt0075314         8.2    808582.0
# 4                   US      NaN  tt0075314         8.2    808582.0
#
#    tmdb_popularity  tmdb_score person_id             name  \
# 0           40.965       8.179      3748   Robert De Niro
# 1           40.965       8.179     14658     Jodie Foster
# 2           40.965       8.179      7064    Albert Brooks
# 3           40.965       8.179      3739    Harvey Keitel
# 4           40.965       8.179     48933  Cybill Shepherd
#
#                  character   role
# 0            Travis Bickle  ACTOR
# 1            Iris Steensma  ACTOR
# 2                      Tom  ACTOR
# 3  Matthew 'Sport' Higgins  ACTOR
# 4                    Betsy  ACTOR

# %% [markdown]
# ### 我们需要的数据有person_id、genres和imdb_scores，所以将其提取出来

# %%
person_id_genres_with_imdb_score=titles_with_credits[["person_id","genres","imdb_score"]]
person_id_genres_with_imdb_score.head()
# Out:
#   person_id genres  imdb_score
# 0      3748  drama         8.2
# 1     14658  drama         8.2
# 2      7064  drama         8.2
# 3      3739  drama         8.2
# 4     48933  drama         8.2

# %% [markdown]
# ### 为了找到各个流派里平均分最高的演员，我们需要先按照流派分组，再按照演员分组，然后求平均分

# %%
genres_person_id_with_mean=person_id_genres_with_imdb_score.groupby(["genres","person_id"])["imdb_score"].mean()
genres_person_id_with_mean.head()
# Out:
# genres  person_id
# action  1000         6.866667
#         100007       7.000000
#         100013       6.400000
#         100019       6.500000
#         100020       6.500000
# Name: imdb_score, dtype: float64

# %% [markdown]
# ### 然后可以将其转换为一个DataFrame

# %%
genres_person_id_with_mean_df=genres_person_id_with_mean.reset_index()
genres_person_id_with_mean_df.head()
# Out:
#    genres person_id  imdb_score
# 0  action      1000    6.866667
# 1  action    100007    7.000000
# 2  action    100013    6.400000
# 3  action    100019    6.500000
# 4  action    100020    6.500000

# %% [markdown]
# ### 这样我们就得到了各个流派各个演员的平均分，然后再求最大值

# %%
genres_with_max=genres_person_id_with_mean_df.groupby("genres")["imdb_score"].max()
genres_with_max
# Out:
# genres
# action           9.3
# animation        9.3
# comedy           9.2
# crime            9.5
# documentation    9.1
# drama            9.5
# european         8.9
# family           9.3
# fantasy          9.3
# history          9.1
# horror           9.0
# music            8.8
# reality          8.9
# romance          9.2
# scifi            9.3
# sport            9.1
# thriller         9.5
# war              8.8
# western          8.9
# Name: imdb_score, dtype: float64

# %% [markdown]
# ### 然后再将这个得到的各个流派的最高分和带有person_id的DataFrame进行连接

# %%
genres_person_id_with_max=pd.merge(genres_with_max,genres_person_id_with_mean_df,on=["genres","imdb_score"])
genres_person_id_with_max
# Out:
#             genres  imdb_score person_id
# 0           action         9.3     12790
# 1           action         9.3      1303
# 2           action         9.3     21033
# 3           action         9.3    336830
# 4           action         9.3     86591
# 5        animation         9.3      1303
# 6        animation         9.3     21033
# 7        animation         9.3     28024
# 8        animation         9.3    336830
# 9        animation         9.3     86591
# 10          comedy         9.2    101292
# 11          comedy         9.2    103374
# 12          comedy         9.2   1296454
# 13          comedy         9.2    140194
# 14          comedy         9.2    140196
# 15          comedy         9.2     38441
# 16          comedy         9.2     44199
# 17          comedy         9.2     71076
# 18          comedy         9.2    747462
# 19           crime         9.5     20552
# 20           crime         9.5     37752
# 21           crime         9.5     85485
# 22   documentation         9.1     22385
# 23   documentation         9.1     36303
# 24   documentation         9.1    408553
# 25   documentation         9.1    439923
# 26   documentation         9.1    479703
# 27           drama         9.5     20552
# 28           drama         9.5     37752
# 29        european         8.9    107375
# 30        european         8.9    107380
# 31        european         8.9    170376
# 32        european         8.9    317847
# 33        european         8.9    727786
# 34        european         8.9    727787
# 35        european         8.9     86802
# 36          family         9.3      1303
# 37          family         9.3     21033
# 38          family         9.3     28024
# 39          family         9.3    336830
# 40          family         9.3     86591
# 41         fantasy         9.3      1303
# 42         fantasy         9.3     21033
# 43         fantasy         9.3     28024
# 44         fantasy         9.3    336830
# 45         fantasy         9.3     86591
# 46         history         9.1     22385
# 47         history         9.1     36303
# 48         history         9.1    408553
# 49         history         9.1    439923
# 50         history         9.1    479703
# 51          horror         9.0       140
# 52          horror         9.0     39331
# 53          horror         9.0    453970
# 54          horror         9.0     86694
# 55           music         8.8   1033815
# 56           music         8.8   1284975
# 57           music         8.8    129032
# 58           music         8.8     14204
# 59           music         8.8   1625708
# 60           music         8.8      1640
# 61           music         8.8      1641
# 62           music         8.8      1652
# 63           music         8.8     16641
# 64           music         8.8      1710
# 65           music         8.8   1789502
# 66           music         8.8      2150
# 67           music         8.8   2269290
# 68           music         8.8    231310
# 69           music         8.8      2740
# 70           music         8.8     27692
# 71           music         8.8      2806
# 72           music         8.8    294917
# 73           music         8.8      3010
# 74           music         8.8      3011
# 75           music         8.8      3012
# 76           music         8.8      3013
# 77           music         8.8      3014
# 78           music         8.8      3015
# 79           music         8.8      3016
# 80           music         8.8    301776
# 81           music         8.8    351504
# 82           music         8.8    351505
# 83           music         8.8    351506
# 84           music         8.8    351507
# 85           music         8.8    351508
# 86           music         8.8    392464
# 87           music         8.8     46263
# 88           music         8.8      4726
# 89           music         8.8     52379
# 90           music         8.8      5811
# 91           music         8.8     77040
# 92           music         8.8     77136
# 93           music         8.8     77469
# 94           music         8.8     82056
# 95           music         8.8     84050
# 96           music         8.8     85756
# 97           music         8.8     91220
# 98           music         8.8    984016
# 99           music         8.8    984017
# 100          music         8.8    984023
# 101        reality         8.9   1099510
# 102        reality         8.9       614
# 103        reality         8.9    843741
# 104        reality         8.9    958249
# 105        romance         9.2    101292
# 106        romance         9.2    103374
# 107        romance         9.2    103760
# 108        romance         9.2   1296454
# 109        romance         9.2    140194
# 110        romance         9.2    140195
# 111        romance         9.2    140196
# 112        romance         9.2     44199
# 113        romance         9.2     71076
# 114        romance         9.2    747462
# 115          scifi         9.3     12790
# 116          scifi         9.3      1303
# 117          scifi         9.3     21033
# 118          scifi         9.3     28024
# 119          scifi         9.3    336830
# 120          scifi         9.3     86591
# 121          sport         9.1     22385
# 122          sport         9.1     36303
# 123          sport         9.1    408553
# 124          sport         9.1    439923
# 125          sport         9.1    479703
# 126       thriller         9.5     13233
# 127       thriller         9.5     20552
# 128       thriller         9.5     37752
# 129            war         8.8    140181
# 130            war         8.8     47019
# 131            war         8.8    826547
# 132        western         8.9     22311
# 133        western         8.9     28166
# 134        western         8.9     28180
# 135        western         8.9     93017

# %% [markdown]
# ### 得到这个数据后，我们还需要知道每个person_id对应的演员的姓名，所以可以用最开始的那个DataFrame将person_id和name提取出来，但由于一个演员可能出演多部电影，会出现重复数据，所以需要清理重复数据

# %%
person_id_with_name=titles_with_credits[["person_id","name"]].drop_duplicates()
person_id_with_name.head()
# Out:
#   person_id             name
# 0      3748   Robert De Niro
# 1     14658     Jodie Foster
# 2      7064    Albert Brooks
# 3      3739    Harvey Keitel
# 4     48933  Cybill Shepherd

# %%
transition1=pd.merge(person_id_with_name,genres_person_id_with_max,on="person_id")
transition1.head()
# Out:
#   person_id                name   genres  imdb_score
# 0     22311     Koichi Yamadera  western         8.9
# 1      1652          Lukas Haas    music         8.8
# 2      1641   Leonardo DiCaprio    music         8.8
# 3     28180      Unsho Ishizuka  western         8.9
# 4     28166  Megumi Hayashibara  western         8.9

# %% [markdown]
# ### 观察发现genres都是乱序的，因此需要进行分组

# %%
transition2=transition1.sort_values("genres")
transition2.head()
# Out:
#    person_id             name  genres  imdb_score
# 42     12790      Olivia Hack  action         9.3
# 37     86591    Cricket Leigh  action         9.3
# 6     336830  André Sogliuzzo  action         9.3
# 23     21033       Zach Tyler  action         9.3
# 32      1303    Jessie Flower  action         9.3

# %% [markdown]
# ### 又发现索引是混乱的，因此还需要重新设置索引

# %%
transition3=transition2.reset_index()
transition3.head()
# Out:
#    index person_id             name  genres  imdb_score
# 0     42     12790      Olivia Hack  action         9.3
# 1     37     86591    Cricket Leigh  action         9.3
# 2      6    336830  André Sogliuzzo  action         9.3
# 3     23     21033       Zach Tyler  action         9.3
# 4     32      1303    Jessie Flower  action         9.3

# %% [markdown]
# ### 最后删除多出来的index这一列

# %%
final=transition3.drop("index",axis=1)
final.head()
# Out:
#   person_id             name  genres  imdb_score
# 0     12790      Olivia Hack  action         9.3
# 1     86591    Cricket Leigh  action         9.3
# 2    336830  André Sogliuzzo  action         9.3
# 3     21033       Zach Tyler  action         9.3
# 4      1303    Jessie Flower  action         9.3

# %% [markdown]
# ### 最后保存一下数据

# %%
final.to_csv("./FinalResult.csv",index=False)
